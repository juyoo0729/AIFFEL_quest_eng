# %%
pip install langchain langgraph langchain-openai langchain-core langchain-community langchain-experimental fpdf pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\yoehe\appdata\roaming\python\python313\site-packages (1.3.2)
# Requirement already satisfied: langgraph in c:\users\yoehe\appdata\roaming\python\python313\site-packages (1.2.2)
# Requirement already satisfied: langchain-openai in c:\users\yoehe\appdata\roaming\python\python313\site-packages (1.2.2)
# Requirement already satisfied: langchain-core in c:\users\yoehe\appdata\roaming\python\python313\site-packages (1.4.0)
# Requirement already satisfied: langchain-community in c:\users\yoehe\appdata\roaming\python\python313\site-packages (0.4.2)
# Requirement already satisfied: langchain-experimental in c:\users\yoehe\appdata\roaming\python\python313\site-packages (0.4.2)
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langgraph) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langgraph) (3.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-core) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-core) (0.8.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\programdata\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: websockets>=15.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (16.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.24.0)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-openai) (2.38.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.15.0)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\programdata\anaconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.1)
# Requirement already satisfied: regex in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.5.9)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: numpy>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\yoehe\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Collecting pdfminer.six==20251230 (from pdfplumber)
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\programdata\anaconda3\lib\site-packages (from pdfplumber) (12.0.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-5.8.0-py3-none-win_amd64.whl.metadata (68 kB)
# Requirement already satisfied: cryptography>=36.0.0 in c:\programdata\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.23)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------  6.6/6.6 MB 35.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 31.2 MB/s  0:00:00
# Using cached pypdfium2-5.8.0-py3-none-win_amd64.whl (3.8 MB)
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (pyproject.toml): started
#   Building wheel for fpdf (pyproject.toml): finished with status 'done'
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40770 sha256=ebf017932dfa5950a969ab9fcb82031e95abe94be78a09bdcd5d066cba1bc3aa
#   Stored in directory: c:\users\yoehe\appdata\local\pip\cache\wheels\aa\da\11\a3189f34ddc13c26a2d0f329eac46b728c7f31c39e4dc26243
# Successfully built fpdf
# Installing collected packages: fpdf, pypdfium2, pdfminer.six, pdfplumber
#
#    ---------- ----------------------------- 1/4 [pypdfium2]
#    ---------- ----------------------------- 1/4 [pypdfium2]
#    ---------- ----------------------------- 1/4 [pypdfium2]
#    ---------- ----------------------------- 1/4 [pypdfium2]
#    -------------------- ------------------- 2/4 [pdfminer.six]
#    -------------------- ------------------- 2/4 [pdfminer.six]
#    -------------------- ------------------- 2/4 [pdfminer.six]
#    -------------------- ------------------- 2/4 [pdfminer.six]
#    ------------------------------ --------- 3/4 [pdfplumber]
#    ------------------------------ --------- 3/4 [pdfplumber]
#    ---------------------------------------- 4/4 [pdfplumber]
#
# Successfully installed fpdf-1.7.2 pdfminer.six-20251230 pdfplumber-0.11.9 pypdfium2-5.8.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pypdfium2.exe is installed in 'C:\Users\yoehe\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pdfplumber.exe is installed in 'C:\Users\yoehe\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from langchain_core.runnables import RunnableConfig
from langchain_core.messages import AIMessage
from typing import Annotated, Literal
from typing_extensions import TypedDict
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.prompts import PromptTemplate
from langchain_core.tools import tool
from langchain_community.agent_toolkits import FileManagementToolkit
from langchain_experimental.tools.python.tool import PythonAstREPLTool
from pydantic import BaseModel, Field
from fpdf import FPDF
import random
import pdfplumber
import os
import requests
import warnings

warnings.filterwarnings("ignore")
# Out:
# C:\Users\yoehe\AppData\Local\Temp\ipykernel_13028\3254521282.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# C:\Users\yoehe\AppData\Local\Temp\ipykernel_13028\3254521282.py:13: DeprecationWarning: `langchain-experimental` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-experimental/issues/87 for details.
#   from langchain_experimental.tools.python.tool import PythonAstREPLTool

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - [TAVILY](https://www.tavily.com/)는 LLM 모델의 웹서치 기능을 붙여주는 대표적인 API 서비스

# %%
# ⚠️ 업로드 전 삭제 (API 키)
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["TAVILY_API_KEY"] = ""

# %%
# 그래프 상태 정의

class State(TypedDict):
    query : Annotated[str, "User Question"]
    answer : Annotated[str, "LLM response"]
    messages : Annotated[list, add_messages]
    tool_call : Annotated[dict, "Tool Call Result"]

# %%
# LLM 정의
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o",
                             temperature=0)

# %%
@tool
def read_pdf(file_path: str):
    """
    PDF 파일에서 텍스트를 추출하는 도구입니다.
    표 형식 또는 일반 텍스트가 포함된 PDF를 읽고 문자열로 반환합니다.

    file_path 예시: './report.pdf'
    """
    try:
        text = ""
        with pdfplumber.open(file_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
        return text.strip() if text.strip() else "❌ PDF에서 텍스트를 추출할 수 없습니다."
    except Exception as e:
        return f"❌ PDF 읽기 오류: {str(e)}"

# %%
@tool
def write_pdf(content: str, filename: str = "output.pdf", summary: bool =True):
    """
    텍스트를 PDF 파일로 저장하는 도구입니다.
    PDF형태의 문서로 만들어야할 때 이 도구를 사용하세요.
    """

    if summary:
        prompt = PromptTemplate.from_template("""
                당신은 보고서를 작성하는 어시스턴트입니다. 당신에겐 문서 모음이 제공되고 이를 잘 분석하여 보고서를 작성하여야 합니다.
                아래의 content는 문서 모음입니다. 문서의 제목, 본문을 잘 판단하고 정리하여 요약합니다.
                항상 구조화된 출력을 제공하세요.
                항상 마지막엔 인사이트도 첨부합니다.

                content : {content}
                """)

        chain = prompt | llm

        content = chain.invoke({"content":content}).content

    else:
        pass

    font_url = "https://github.com/google/fonts/raw/main/ofl/notosanskr/NotoSansKR%5Bwght%5D.ttf"
    font_path = "./fonts/NotoSansKR.ttf"

    try:
        os.mkdir("./fonts/")
        response = requests.get(font_url)
        with open(font_path, "wb") as f:
            f.write(response.content)
    except:
        pass

    pdf = FPDF()
    pdf.add_page()
    pdf.set_auto_page_break(auto=True, margin=15)

    font_path = "./fonts/NotoSansKR.ttf"  # <-- 여기에 실제 폰트 파일이 있어야 함

    try:
        pdf.add_font("NotoSans", "", font_path, uni=True)
        pdf.set_font("NotoSans", size=12)
    except:
        raise ValueError("한글 폰트를 등록할 수 없습니다.")

    for line in content.split("\n"):
        pdf.multi_cell(0, 10, line)
    pdf.output(f"./{filename}")

    return f"{filename} 저장 완료"

# %%
# 툴 정의
# TavilySearchResults : 웹 검색 도구
# PythonAstREPLTool : 파이썬 코드 실행 도구
# write_pdf : pdf 생성 도구
# read_pdf : pdf 읽기 도구
# file_delete : 파일 삭제 도구
# list_directory : 파일 목록 읽기 도구

tools = [TavilySearchResults(max_results=10), PythonAstREPLTool(), write_pdf, read_pdf, *FileManagementToolkit(
                                                                            selected_tools=["file_delete","list_directory"]).get_tools()]
search_tool, code_tool, write_tool, read_tool, delete_tool, listdir_tool= tools

# %%
# PDF 쓰기 도구 예시

write_tool.invoke({"content":"안녕하세요! \nLanggraph 예제코드입니다.", "filename":"Langgraph_report.pdf", "summary":False})
# Out:
# 'Langgraph_report.pdf 저장 완료'

# %%
# PDF 읽기 도구 예시
print("\n\n", read_tool.invoke(r"C:\AI_study\rag-study\Langgraph_report.pdf"))
# Out:
#  안녕하세요!
# Langgraph 예제코드입니다.

# %%
# 파일 목록 도구 예시

print(listdir_tool.invoke(input=""))
# Out:
# .venv
# athlete_events.csv
# Day1_RAG.ipynb
# Day1_RAG.pptx
# Day1_RAG_Code.ipynb
# Day2_1_RAG_Family.ipynb
# Day2_2_Rag_evaluation.ipynb
# Day2_Practice.ipynb
# Day2_RAG_student.pptx
# Day4_AgenticAI_Code_1_Langgraph_tutorial.ipynb
# Day4_AgenticAI_Code_2_Langgraph_Exercise.ipynb
# Day4_AgenticAI_Code_3_Autogen_Tutorial.ipynb
# Day4_AgenticAI_Code_4_Autogen_Exercise.ipynb
# Day4_AgenticAI_Principle.ipynb
# Day4_AgenticAI_student.pptx
# Demian.pdf
# fonts
# Langgraph_report.pdf
# local_RAG_튜토리얼.md
# ragas-env
# state_of_the_union.txt
# titanic.csv
# Untitled-1.ipynb

# %%
# 삭제 도구 예시

delete_tool.invoke("Langgraph_report.pdf")
# Out:
# 'File deleted successfully: Langgraph_report.pdf.'

# %%
# LLM에게 도구 할당

llm_with_tools = llm.bind_tools(tools)

# %%
# 전체 메시지 중 마지막 메시지를 제외하고 최대 8개까지 단기 기억(history)으로 추출

def shorterm_memory(state:State):

    if len(state["messages"]) > 8:
        history = state["messages"][-8:-1]
    elif len(state["messages"]) == 1:
        history = ""
    else:
        history = state["messages"][:-1]

    return history

# %%
class HistoryChecker(BaseModel):
    """
    이전의 대화 기록을 참고하여 질문에 대해 답변할 수 있는지 판단합니다.
    답변할 수 있다면 "yes", 답변할 수 없다면 "no"를 반환합니다.
    """

    yes_no : Literal["yes", "no"] = Field(..., description="""Use your previous conversation history to determine if you can answer your questions.
    Return "yes" if you can answer, "no" if you can't answer.""")

# %%
# 히스토리 기반 답변 분기를 위한 함수 설정

def history_check(state:State):

    prompt = PromptTemplate.from_template("""

                이전의 대화 기록을 참고하여 질문에 대해 답변할 수 있는지 판단합니다.
                답변할 수 있다면 "yes", 답변할 수 없다면 "no"를 반환합니다.

                대화 기록 : {history}

                질문 : {query}

                """)

    chain = prompt | history_checker

    history = shorterm_memory(state)

    result = chain.invoke({"history":history,
                            "query":state["query"]})

    return result.yes_no

# %%
# LLM의 응답을 HistoryChecker 클래스 구조에 맞춰 파싱하도록 설정

history_checker = llm.with_structured_output(HistoryChecker)

# %%
# 기억 기반 답변 노드

def memory_chat(state:State):

    prompt = PromptTemplate.from_template("""

                이전의 대화 기록을 참고하여 질문에 대해 답변하세요.
                아래 대화 기록을 첨부합니다.
                대화 기록을 통해 답변이 어렵다면 내부 지식을 참조하세요.

                대화 기록 : {history}

                질문 : {query}

                """)


    chain = prompt | llm

    history = shorterm_memory(state)

    result = chain.invoke({"history":history,
                           "query":state["query"]})

    if len(state["tool_call"]) == 0:
        return {"answer":result.content,
                "messages":result,
                "tool_call":"사용된 기록 없음."}
    else:
        return {"answer":result.content,
                "messages":result}

# %%
# 기억 기반 답변 분기 노드

def history_node(state:State):
    if len(state["messages"]) == 1:
        return {"answer":"답변 없음",
                "tool_call":"사용된 도구 없음"}
    else:
        return state

# %%
# 도구 선택 노드

def select(
    state: State,
):

    prompt = PromptTemplate.from_template("""

                이전의 대화 기록을 참고하여 질문에 대해 답변하세요.
                아래 대화 기록을 첨부합니다.
                이전의 대화가 다음에 어떤 도구를 사용해야하는지 힌트가 될 수 있습니다. 꼭 참조하세요.
                도구의 변화가 큰 결과를 가져올 수 있습니다.
                들어온 메시지, 정답, 이전 기록을 모두 분석하여 가장 적절한 도구를 선택하세요.

                대화 기록 : {history}

                최근 사용한 도구 : {tool_name}

                정답 : {answer}

                질문 : {query}

                """)

    chain = prompt | llm_with_tools

    history = shorterm_memory(state)

    result = chain.invoke({"history" : history,
                           "tool_name" : state["tool_call"],
                            "answer": state["answer"],
                            "query": state["query"]})

    if hasattr(result, "tool_calls") and len(result.tool_calls) > 0:
        tool_calls = result.tool_calls

        return {"messages": result,
                "tool_call":tool_calls}
    else:
        return {"messages":AIMessage(content=f"""도구를 선택하지 못했습니다. 적절한 도구를 재선택하세요.
                                        """),
                                    "tool_call":"선택된 도구 없음"}

# %%
# 도구 실행 노드

tool_node = ToolNode(tools)

# %%
class AnswerChecker(BaseModel):
    """
    정답 분류기입니다.

    정답이 질문을 해결했는지 여부를 판단합니다.
    질문을 해결하지 못했을 시 해결될 때까지 도구를 이용합니다.

    질문을 해결했다면 "end", 해결하지 못했다면 "tool"을 반환합니다.
    """


    end : Literal["end", "tool"] = Field(..., description="""You are the answer sorter.

                                                                Determine if the correct answer has solved the question.
                                                                If the question is not resolved, use the tool until it is resolved.

                                                                Return "end" if you solved the question, or "tool" if you didn't.""")

# %%
# LLM의 응답을 AnswerChecker 클래스 구조에 맞춰 파싱하도록 설정

answer_checker = llm.with_structured_output(AnswerChecker)

# %%
# 답변 확인 노드

def response(state:State):

    return {"answer":state["messages"][-1]}

# %%
# 답변 완성 판단 분기 함수

def answer_check(state:State):

    prompt = PromptTemplate.from_template("""
    당신은 정답 분류기 어시스턴트입니다.

    정답이 질문을 해결하였는지 여부를 판단합니다.
    질문을 해결하지 못했다면 도구를 이용합니다.

    질문을 해결하였다면 "end", 아니라면 "tool"을 반환합니다.

    기존 History도 참고하여 답변하세요.

    History : {history}

    정답 : {answer}

    질문 : {query}
    """)

    chain = prompt | answer_checker

    history = shorterm_memory(state)

    result = chain.invoke({"history" : history,
                            "answer": state["answer"],
                            "query": state["query"]})

    return result.end

# %%
# 그래프 정의

graph_builder = StateGraph(State)

# %%
# 노드 및 엣지 정의

graph_builder.add_node("history_node", history_node)
graph_builder.add_node("memory_chat", memory_chat)
graph_builder.add_node("select", select)
graph_builder.add_node("tools", tool_node)
graph_builder.add_node("response", response)


graph_builder.add_edge(START, "history_node")
graph_builder.add_conditional_edges("history_node",
                            history_check,
                            {"yes":"memory_chat",
                             "no":"select"})
graph_builder.add_edge("select", "tools")
graph_builder.add_edge("tools", "response")
graph_builder.add_edge("memory_chat", "response")
graph_builder.add_conditional_edges("response",
                                    answer_check,
                                    {"end":END,
                                    "tool":"select"});

# %%
# 메모리 설정 및 그래프 컴파일

memory = MemorySaver()

graph = graph_builder.compile(checkpointer=memory)

# %%
# 그래프 시각화
# 가끔 "ReadTimeout: HTTPSConnectionPool(host='mermaid.ink', port=443): Read timed out. (read timeout=10)"라는 에러가 발생
# 시간 초과로 그래프 생성에 실패했다는 메시지일뿐 기능과는 관계없으니 진행해도 괜찮습니다.

graph

# %%
# config 재생성 노드, config의 재사용은 고려되지 않음. 재사용한다면 변수에 할당하여 사용할 것

def reset_config(limit=20):

    thread_id=random.randint(1,999999)

    config = RunnableConfig(recursion_limit=limit, configurable={"thread_id": thread_id})

    return config

# %%
# 출력 함수 정의
# mode = "values" : 상태의 키, 값의 형태로 반환
# mode = "updates" : 업데이트되는 값만 반환

def streaming(query, config, mode="values"):

    result = graph.stream({"messages":("user", query),
                         "query":query}, config=config, stream_mode=mode)

    if mode == "values":
        for step in result:
            for k, v in step.items():
                if k == "messages":
                    v[-1].pretty_print()
    elif mode == "updates":
        for step in result:
            for k,v in step.items():
                print(f"\n\n=== {k} ===\n\n")
                print(v)

    return

# %%
config = reset_config()

query = "1+1은 뭔가요?"

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# 1+1은 뭔가요?
# ================================ Human Message =================================
#
# 1+1은 뭔가요?
# ================================== Ai Message ==================================
#
# 1+1은 2입니다.
# ================================== Ai Message ==================================
#
# 1+1은 2입니다.

# %%
config = reset_config()

query = "현대자동차라는 회사에 대해 조사해주세요. 잘 정리된 보고서를 제공해주십시오. pdf 포멧의 파일로 받기를 희망합니다."

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# 현대자동차라는 회사에 대해 조사해주세요. 잘 정리된 보고서를 제공해주십시오. pdf 포멧의 파일로 받기를 희망합니다.
# ================================ Human Message =================================
#
# 현대자동차라는 회사에 대해 조사해주세요. 잘 정리된 보고서를 제공해주십시오. pdf 포멧의 파일로 받기를 희망합니다.
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_uUEE5MQdyrbhQxQeXcRu014Q)
#  Call ID: call_uUEE5MQdyrbhQxQeXcRu014Q
#   Args:
#     query: Hyundai Motor Company overview 2023
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "
n\n## Social\n\n## Get our free apps\n\nScribd - Download on the App Store\nScribd - Get it on Google Play\n\n## About\n\n## Legal\n\n## Support\n\n## Social\n\n## Get our free apps\n\nScribd - Download on the App Store\nScribd - Get it on Google Play", "score": 0.9549888}, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "HYUNDAI WIA publishes a sustainability report annually to share our performance and future direction with stakeholders in a transparent manner. This report contains not only information about the present and future of the company but also our efforts to contribute to our corporate suppliers and local society. All executives and employees of HYUNDAI WIA pledge to devote themselves in creating a sustainable company and society, and I would like to share with you in more detail about the direction we will be taking this year.\nFirst, we will transform our business structure to carry out sustainable businesses. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure.", "score": 0.9500091}, {"title": "[PDF] 2024 Sustainability Report - Hyundai Worldwide", "url": "https://www.hyundai.com/content/dam/hyundai/kr/ko/data/company-report/2024/07/10/hmc-sr-en-2024.pdf", "content": "Company Overview  As of Dec. 31, 2023; Based on K-IFRS consolidated financial statements Hyundai Motor Company has been p ...

# %%
query = "현대자동차의 경쟁사에 대한 정보도 정리된 보고서를 작성해주세요."

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# 현대자동차의 경쟁사에 대한 정보도 정리된 보고서를 작성해주세요.
# ================================ Human Message =================================
#
# 현대자동차의 경쟁사에 대한 정보도 정리된 보고서를 작성해주세요.
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_eRhUEIpwBtDU9RbOg9WXkJEe)
#  Call ID: call_eRhUEIpwBtDU9RbOg9WXkJEe
#   Args:
#     query: Hyundai Motor Company competitors overview 2023
#   tavily_search_results_json (call_dcVxvSnK3lPoPkY9h5VyTHRd)
#  Call ID: call_dcVxvSnK3lPoPkY9h5VyTHRd
#   Args:
#     query: Hyundai Motor Company competitors financial performance 2023
#   tavily_search_results_json (call_RQ7DVtJbE70I18ThUDKwO9W1)
#  Call ID: call_RQ7DVtJbE70I18ThUDKwO9W1
#   Args:
#     query: Hyundai Motor Company competitors sustainability report 2023
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Road to Sustainability", "url": "https://www.hyundai.com/content/dam/hyundai/ww/en/images/company/sustainability/about-sustainability/hmc-2023-sustainability-report-en-v5.pdf", "content": "Stakeholder Engagement Materiality Analysis Hyundai conducted the 2023 materiality analysis to identify material issues – leading the transition to eco-friendly/electric vehicles, efforts to reduce GHG emissions, enhancement of global corporate value, diffusion of human rights management, and strategic management of supply chain ESG. They have continuity with the material issues in the last report. “Leading the transition to eco-friendly/electric vehicles” was chosen as the most important issue this year, reflecting anticipations toward the eco-friendly and electrification transition strategies of Hyundai as the leader of the future mobility industry amid a global trend of switching to EVs. In addition, “diffusion of human rights management” and “strategic management of supply chain ESG” [...] 55 \u0007 Hyundai Motor Manufacturing Alabama 56 \u0007 Hyundai Motor Central & South America Headquarters 57 Hyundai Motor de Mexico 58 Hyundai de Mexico 59 Hyundai Translead 60 Hyundai Motor America 61 \u0007 Hyundai Motor Company Washington Office 62 Motional 63 Supernal 64 North America Quality Center 65 Boston Dynamics North America, Central & South America  As of April 2023 06 ESG Magazine 2. Environmental 3. Social 4. Governance 5. ESG Factbook 1. Introduction Business Performance Hyundai sells vehicles through directly-operated branches across Korea as well as dealerships. To increase sales, we implement customer top priority management, marketing aimed at enhancing brand value, and on-site-tailored sales promotions. We implement innovative activities to respond to consumer needs in the [...] Hyundai Motor Group’s mid- to long-term hydrogen business strategies and phased roadmap Efforts to reduce GHG emissions Leading the transition to eco-friendly/electric vehicles Enhancement of global corporate value Results of selecting 2023 material issues No.", "score": 0.8793233}, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] HYUNDAI WIA prioritizes health and safety issues all business activities in accordance with the management policy of prioritizing health and safety. The company has set “Zero Accidents,” “Safety Culture,” and “Zero Major Accidents” as its  ...
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Road to Sustainability", "url": "https://www.hyundai.com/content/dam/hyundai/ww/en/images/company/sustainability/about-sustainability/hmc-2023-sustainability-report-en-v5.pdf", "content": "Stakeholder Engagement Materiality Analysis Hyundai conducted the 2023 materiality analysis to identify material issues – leading the transition to eco-friendly/electric vehicles, efforts to reduce GHG emissions, enhancement of global corporate value, diffusion of human rights management, and strategic management of supply chain ESG. They have continuity with the material issues in the last report. “Leading the transition to eco-friendly/electric vehicles” was chosen as the most important issue this year, reflecting anticipations toward the eco-friendly and electrification transition strategies of Hyundai as the leader of the future mobility industry amid a global trend of switching to EVs. In addition, “diffusion of human rights management” and “strategic management of supply chain ESG” [...] 55 \u0007 Hyundai Motor Manufacturing Alabama 56 \u0007 Hyundai Motor Central & South America Headquarters 57 Hyundai Motor de Mexico 58 Hyundai de Mexico 59 Hyundai Translead 60 Hyundai Motor America 61 \u0007 Hyundai Motor Company Washington Office 62 Motional 63 Supernal 64 North America Quality Center 65 Boston Dynamics North America, Central & South America  As of April 2023 06 ESG Magazine 2. Environmental 3. Social 4. Governance 5. ESG Factbook 1. Introduction Business Performance Hyundai sells vehicles through directly-operated branches across Korea as well as dealerships. To increase sales, we implement customer top priority management, marketing aimed at enhancing brand value, and on-site-tailored sales promotions. We implement innovative activities to respond to consumer needs in the [...] Hyundai Motor Group’s mid- to long-term hydrogen business strategies and phased roadmap Efforts to reduce GHG emissions Leading the transition to eco-friendly/electric vehicles Enhancement of global corporate value Results of selecting 2023 material issues No.", "score": 0.8793233}, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] HYUNDAI WIA prioritizes health and safety issues all business activities in accordance with the management policy of prioritizing health and safety. The company has set “Zero Accidents,” “Safety Culture,” and “Zero Major Accidents” as its  ...
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_aKWijbKey2GwJ8znWd0B1IRD)
#  Call ID: call_aKWijbKey2GwJ8znWd0B1IRD
#   Args:
#     query: Hyundai Motor Company competitors overview 2023
#   tavily_search_results_json (call_YVdMvhdnMHuSqFe4RQkQyiQ8)
#  Call ID: call_YVdMvhdnMHuSqFe4RQkQyiQ8
#   Args:
#     query: Hyundai Motor Company competitors financial performance 2023
#   tavily_search_results_json (call_jamAL586dxxNoFWfsWM1rop2)
#  Call ID: call_jamAL586dxxNoFWfsWM1rop2
#   Args:
#     query: Hyundai Motor Company competitors sustainability report 2023
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "
, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] HYUNDAI WIA prioritizes health and safety issues all business activities in accordance with the management policy of prioritizing health and safety. The company has set “Zero Accidents,” “Safety Culture,” and “Zero Major Accidents” as its  ...
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_qgvXSQjxWb9x1m1UbBsRDnlP)
#  Call ID: call_qgvXSQjxWb9x1m1UbBsRDnlP
#   Args:
#     query: Hyundai Motor Company competitors overview 2023
#   tavily_search_results_json (call_BD0RwQS6kgy184DntfhIbuhq)
#  Call ID: call_BD0RwQS6kgy184DntfhIbuhq
#   Args:
#     query: Hyundai Motor Company competitors financial performance 2023
#   tavily_search_results_json (call_IUt9Wpia1NAh6Pt6S7Re6AKE)
#  Call ID: call_IUt9Wpia1NAh6Pt6S7Re6AKE
#   Args:
#     query: Hyundai Motor Company competitors sustainability report 2023
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Road to Sustainability", "url": "https://www.hyundai.com/content/dam/hyundai/ww/en/images/company/sustainability/about-sustainability/hmc-2023-sustainability-report-en-v5.pdf", "content": "Stakeholder Engagement Materiality Analysis Hyundai conducted the 2023 materiality analysis to identify material issues – leading the transition to eco-friendly/electric vehicles, efforts to reduce GHG emissions, enhancement of global corporate value, diffusion of human rights management, and strategic management of supply chain ESG. They have continuity with the material issues in the last report. “Leading the transition to eco-friendly/electric vehicles” was chosen as the most important issue this year, reflecting anticipations toward the eco-friendly and electrification transition strategies of Hyundai as the leader of the future mobility industry amid a global trend of switching to EVs. In addition, “diffusion of human rights management” and “strategic management of supply chain ESG” [...] 55 \u0007 Hyundai Motor Manufacturing Alabama 56 \u0007 Hyundai Motor Central & South America Headquarters 57 Hyundai Motor de Mexico 58 Hyundai de Mexico 59 Hyundai Translead 60 Hyundai Motor America 61 \u0007 Hyundai Motor Company Washington Office 62 Motional 63 Supernal 64 North America Quality Center 65 Boston Dynamics North America, Central & South America  As of April 2023 06 ESG Magazine 2. Environmental 3. Social 4. Governance 5. ESG Factbook 1. Introduction Business Performance Hyundai sells vehicles through directly-operated branches across Korea as well as dealerships. To increase sales, we implement customer top priority management, marketing aimed at enhancing brand value, and on-site-tailored sales promotions. We implement innovative activities to respond to consumer needs in the [...] Hyundai Motor Group’s mid- to long-term hydrogen business strategies and phased roadmap Efforts to reduce GHG emissions Leading the transition to eco-friendly/electric vehicles Enhancement of global corporate value Results of selecting 2023 material issues No.", "score": 0.8793233}, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] HYUNDAI WIA prioritizes health and safety issues all business activities in accordance with the management policy of prioritizing health and safety. The company has set “Zero Accidents,” “Safety Culture,” and “Zero Major Accidents” as its  ...
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Road to Sustainability", "url": "https://www.hyundai.com/content/dam/hyundai/ww/en/images/company/sustainability/about-sustainability/hmc-2023-sustainability-report-en-v5.pdf", "content": "Stakeholder Engagement Materiality Analysis Hyundai conducted the 2023 materiality analysis to identify material issues – leading the transition to eco-friendly/electric vehicles, efforts to reduce GHG emissions, enhancement of global corporate value, diffusion of human rights management, and strategic management of supply chain ESG. They have continuity with the material issues in the last report. “Leading the transition to eco-friendly/electric vehicles” was chosen as the most important issue this year, reflecting anticipations toward the eco-friendly and electrification transition strategies of Hyundai as the leader of the future mobility industry amid a global trend of switching to EVs. In addition, “diffusion of human rights management” and “strategic management of supply chain ESG” [...] 55 \u0007 Hyundai Motor Manufacturing Alabama 56 \u0007 Hyundai Motor Central & South America Headquarters 57 Hyundai Motor de Mexico 58 Hyundai de Mexico 59 Hyundai Translead 60 Hyundai Motor America 61 \u0007 Hyundai Motor Company Washington Office 62 Motional 63 Supernal 64 North America Quality Center 65 Boston Dynamics North America, Central & South America  As of April 2023 06 ESG Magazine 2. Environmental 3. Social 4. Governance 5. ESG Factbook 1. Introduction Business Performance Hyundai sells vehicles through directly-operated branches across Korea as well as dealerships. To increase sales, we implement customer top priority management, marketing aimed at enhancing brand value, and on-site-tailored sales promotions. We implement innovative activities to respond to consumer needs in the [...] Hyundai Motor Group’s mid- to long-term hydrogen business strategies and phased roadmap Efforts to reduce GHG emissions Leading the transition to eco-friendly/electric vehicles Enhancement of global corporate value Results of selecting 2023 material issues No.", "score": 0.8793233}, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] HYUNDAI WIA prioritizes health and safety issues all business activities in accordance with the management policy of prioritizing health and safety. The company has set “Zero Accidents,” “Safety Culture,” and “Zero Major Accidents” as its  ...
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_PcWXXnVj3rL4739eJw0ShKpp)
#  Call ID: call_PcWXXnVj3rL4739eJw0ShKpp
#   Args:
#     query: Hyundai Motor Company competitors overview 2023
#   tavily_search_results_json (call_xdrDg7RWtkxzDiTCeFhKjlLP)
#  Call ID: call_xdrDg7RWtkxzDiTCeFhKjlLP
#   Args:
#     query: Hyundai Motor Company competitors financial performance 2023
#   tavily_search_results_json (call_qnrcbbQEmD6fNSAyEj8nONzh)
#  Call ID: call_qnrcbbQEmD6fNSAyEj8nONzh
#   Args:
#     query: Hyundai Motor Company competitors sustainability report 2023
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Road to Sustainability", "url": "https://www.hyundai.com/content/dam/hyundai/ww/en/images/company/sustainability/about-sustainability/hmc-2023-sustainability-report-en-v5.pdf", "content": "Stakeholder Engagement Materiality Analysis Hyundai conducted the 2023 materiality analysis to identify material issues – leading the transition to eco-friendly/electric vehicles, efforts to reduce GHG emissions, enhancement of global corporate value, diffusion of human rights management, and strategic management of supply chain ESG. They have continuity with the material issues in the last report. “Leading the transition to eco-friendly/electric vehicles” was chosen as the most important issue this year, reflecting anticipations toward the eco-friendly and electrification transition strategies of Hyundai as the leader of the future mobility industry amid a global trend of switching to EVs. In addition, “diffusion of human rights management” and “strategic management of supply chain ESG” [...] 55 \u0007 Hyundai Motor Manufacturing Alabama 56 \u0007 Hyundai Motor Central & South America Headquarters 57 Hyundai Motor de Mexico 58 Hyundai de Mexico 59 Hyundai Translead 60 Hyundai Motor America 61 \u0007 Hyundai Motor Company Washington Office 62 Motional 63 Supernal 64 North America Quality Center 65 Boston Dynamics North America, Central & South America  As of April 2023 06 ESG Magazine 2. Environmental 3. Social 4. Governance 5. ESG Factbook 1. Introduction Business Performance Hyundai sells vehicles through directly-operated branches across Korea as well as dealerships. To increase sales, we implement customer top priority management, marketing aimed at enhancing brand value, and on-site-tailored sales promotions. We implement innovative activities to respond to consumer needs in the [...] Hyundai Motor Group’s mid- to long-term hydrogen business strategies and phased roadmap Efforts to reduce GHG emissions Leading the transition to eco-friendly/electric vehicles Enhancement of global corporate value Results of selecting 2023 material issues No.", "score": 0.8793233}, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] HYUNDAI WIA prioritizes health and safety issues all business activities in accordance with the management policy of prioritizing health and safety. The company has set “Zero Accidents,” “Safety Culture,” and “Zero Major Accidents” as its  ...
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Road to Sustainability", "url": "https://www.hyundai.com/content/dam/hyundai/ww/en/images/company/sustainability/about-sustainability/hmc-2023-sustainability-report-en-v5.pdf", "content": "Stakeholder Engagement Materiality Analysis Hyundai conducted the 2023 materiality analysis to identify material issues – leading the transition to eco-friendly/electric vehicles, efforts to reduce GHG emissions, enhancement of global corporate value, diffusion of human rights management, and strategic management of supply chain ESG. They have continuity with the material issues in the last report. “Leading the transition to eco-friendly/electric vehicles” was chosen as the most important issue this year, reflecting anticipations toward the eco-friendly and electrification transition strategies of Hyundai as the leader of the future mobility industry amid a global trend of switching to EVs. In addition, “diffusion of human rights management” and “strategic management of supply chain ESG” [...] 55 \u0007 Hyundai Motor Manufacturing Alabama 56 \u0007 Hyundai Motor Central & South America Headquarters 57 Hyundai Motor de Mexico 58 Hyundai de Mexico 59 Hyundai Translead 60 Hyundai Motor America 61 \u0007 Hyundai Motor Company Washington Office 62 Motional 63 Supernal 64 North America Quality Center 65 Boston Dynamics North America, Central & South America  As of April 2023 06 ESG Magazine 2. Environmental 3. Social 4. Governance 5. ESG Factbook 1. Introduction Business Performance Hyundai sells vehicles through directly-operated branches across Korea as well as dealerships. To increase sales, we implement customer top priority management, marketing aimed at enhancing brand value, and on-site-tailored sales promotions. We implement innovative activities to respond to consumer needs in the [...] Hyundai Motor Group’s mid- to long-term hydrogen business strategies and phased roadmap Efforts to reduce GHG emissions Leading the transition to eco-friendly/electric vehicles Enhancement of global corporate value Results of selecting 2023 material issues No.", "score": 0.8793233}, {"title": "[PDF] SUSTAINABILITY REPORT 2023 - HYUNDAI WIA", "url": "http://en.hyundai-wia.com/upload/download/2023_Sustainability_En_2.0.pdf", "content": "In order to respond to the rapidly changing external environment in 2023, HYUNDAI WIA will drastically change our business structure. We will review the effectiveness of low-margin businesses that are not in line with our direction of growth and reorganize our business portfolio, centering the future businesses such as integrated thermal management systems, electrified torque vectoring systems, and smart manufacturing solutions based on robotics and autonomous driving technologies. This year, we will invest more manpower and material resources in these future businesses and pave the foundation for the sustainability of our company. Second, we will strengthen risk management and diversify our profit structure. [...] SUSTAINABILITY REPORT 2023 17 Dual Materiality Assessment Materiality Assessment Assessment Process HYUNDAI WIA has adopted the double materiality concept presented in the EU’s Corporate Sustainability Reporting Directive (CSRD) to select material issues for the materiality assessment in this year. Double materiality indicates how a company should consider the impact of sustainability issues on the company's value, such as growth, performance, and risk factors, as well as the impact that the company poses on the environment and society. This means that a company must consider both internal and external perspectives. We aim to proactively identify and manage sustainability-related issues in relation to the internal and external impacts of our business activities. [...] HYUNDAI WIA prioritizes health and safety issues all business activities in accordance with the management policy of prioritizing health and safety. The company has set “Zero Accidents,” “Safety Culture,” and “Zero Major Accidents” as its  ...
# ================================== Ai Message ==================================
# Tool Calls:
#   write_pdf (call_CJ3V0h74OKQhJc5dod7Wdhx3)
#  Call ID: call_CJ3V0h74OKQhJc5dod7Wdhx3
#   Args:
#     content: ### Hyundai Motor Company Competitors Overview 2023
#
# 1. **Competitive Landscape**
#    - Hyundai's commitment to innovation is a cornerstone of its competitive advantages. The company has made substantial investments in electric vehicles, hydrogen fuel cell technology, and autonomous driving systems.
#    - Key competitors include Toyota, Volkswagen, General Motors, Ford, and Nissan, each bringing unique strengths such as Toyota's hybrid technology and Volkswagen's broad brand portfolio.
#
# 2. **Financial Performance**
#    - Hyundai Motor Company sold 4,216,898 vehicles worldwide in 2023, marking a 7% increase from 2022.
#    - The company's annual revenue increased by 14.4% to KRW 162.7 trillion, with an operating profit margin of 9.3%.
#    - Hyundai's net profit climbed 54% to KRW 12.27 trillion.
#
# 3. **Sustainability Efforts**
#    - Hyundai is leading the transition to eco-friendly vehicles, focusing on reducing GHG emissions and enhancing global corporate value.
#    - The company has faced criticism for underreporting greenhouse gas emissions and has been involved in controversies regarding labor practices.
#    - Hyundai's sustainability strategy includes a focus on electrification and strategic management of supply chain ESG.
#
# 4. **Strategic Initiatives**
#    - Hyundai plans to expand its investment to KRW 12.4 trillion in 2024, focusing on capital expenditure, research and development, and strategic investments.
#    - The company aims to sell more than 4.24 million vehicles in 2024, with a focus on expanding its electric vehicle lineup.
#
# 5. **Challenges and Opportunities**
#    - Hyundai faces challenges such as increased competition in the EV market and labor issues in its supply chain.
#    - Opportunities include leveraging its technological advancements and strategic alliances to enhance market entry in advanced automotive sectors.
#
# This report provides a comprehensive overview of Hyundai Motor Company's competitive landscape, financial performance, sustainability efforts, strategic initiatives, and the challenges and opportunities it faces in the automotive industry.
#     filename: Hyundai_Competitors_Report_2023.pdf
# ================================= Tool Message =================================
# Name: write_pdf
#
# Hyundai_Competitors_Report_2023.pdf 저장 완료
# ================================= Tool Message =================================
# Name: write_pdf
#
# Hyundai_Competitors_Report_2023.pdf 저장 완료

# %%
config = reset_config()

query = "현재 폴더의 pdf로 이루어진 파일 모두 삭제해줘"

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# 현재 폴더의 pdf로 이루어진 파일 모두 삭제해줘
# ================================ Human Message =================================
#
# 현재 폴더의 pdf로 이루어진 파일 모두 삭제해줘
# ================================== Ai Message ==================================
# Tool Calls:
#   list_directory (call_n47slR91Ng7MZvmbHH5WHPyk)
#  Call ID: call_n47slR91Ng7MZvmbHH5WHPyk
#   Args:
#     dir_path: .
# ================================= Tool Message =================================
# Name: list_directory
#
# .venv
# athlete_events.csv
# Day1_RAG.ipynb
# Day1_RAG.pptx
# Day1_RAG_Code.ipynb
# Day2_1_RAG_Family.ipynb
# Day2_2_Rag_evaluation.ipynb
# Day2_Practice.ipynb
# Day2_RAG_student.pptx
# Day4_AgenticAI_Code_1_Langgraph_tutorial.ipynb
# Day4_AgenticAI_Code_2_Langgraph_Exercise.ipynb
# Day4_AgenticAI_Code_3_Autogen_Tutorial.ipynb
# Day4_AgenticAI_Code_4_Autogen_Exercise.ipynb
# Day4_AgenticAI_Principle.ipynb
# Day4_AgenticAI_student.pptx
# Demian.pdf
# fonts
# Hyundai_Competitors_Report_2023.pdf
# local_RAG_튜토리얼.md
# ragas-env
# state_of_the_union.txt
# titanic.csv
# Untitled-1.ipynb
# ================================= Tool Message =================================
# Name: list_directory
#
# .venv
# athlete_events.csv
# Day1_RAG.ipynb
# Day1_RAG.pptx
# Day1_RAG_Code.ipynb
# Day2_1_RAG_Family.ipynb
# Day2_2_Rag_evaluation.ipynb
# Day2_Practice.ipynb
# Day2_RAG_student.pptx
# Day4_AgenticAI_Code_1_Langgraph_tutorial.ipynb
# Day4_AgenticAI_Code_2_Langgraph_Exercise.ipynb
# Day4_AgenticAI_Code_3_Autogen_Tutorial.ipynb
# Day4_AgenticAI_Code_4_Autogen_Exercise.ipynb
# Day4_AgenticAI_Principle.ipynb
# Day4_AgenticAI_student.pptx
# Demian.pdf
# fonts
# Hyundai_Competitors_Report_2023.pdf
# local_RAG_튜토리얼.md
# ragas-env
# state_of_the_union.txt
# titanic.csv
# Untitled-1.ipynb
# ================================== Ai Message ==================================
# Tool Calls:
#   file_delete (call_Is3cTm6vakZbgJpr2ldWlpGU)
#  Call ID: call_Is3cTm6vakZbgJpr2ldWlpGU
#   Args:
#     file_path: ./Demian.pdf
#   file_delete (call_cMfbCgfRqpG3s3LGQwOwoajo)
#  Call ID: call_cMfbCgfRqpG3s3LGQwOwoajo
#   Args:
#     file_path: ./Hyundai_Competitors_Report_2023.pdf
# ================================= Tool Message =================================
# Name: file_delete
#
# File deleted successfully: ./Hyundai_Competitors_Report_2023.pdf.
# ================================= Tool Message =================================
# Name: file_delete
#
# File deleted successfully: ./Hyundai_Competitors_Report_2023.pdf.

# %%
config = reset_config()

code = """
아래 코드 실행시켜주세요.

```python

result = 0

for i in range(20):
    print(f"{i+1}번째 출력: ", i+1)
    result += i

print("최종 결과: ", result)

```
"""

streaming(code, config)
# Out:
# ================================ Human Message =================================
#
#
# 아래 코드 실행시켜주세요.
#
# ```python
#
# result = 0
#
# for i in range(20):
#     print(f"{i+1}번째 출력: ", i+1)
#     result += i
#
# print("최종 결과: ", result)
#
# ```
#
# ================================ Human Message =================================
#
#
# 아래 코드 실행시켜주세요.
#
# ```python
#
# result = 0
#
# for i in range(20):
#     print(f"{i+1}번째 출력: ", i+1)
#     result += i
#
# print("최종 결과: ", result)
#
# ```
#
# ================================== Ai Message ==================================
#
# 이전 대화 기록이 제공되지 않았으므로, 내부 지식을 참조하여 질문에 답변하겠습니다.
#
# 주어진 Python 코드를 실행하면 다음과 같은 결과가 출력됩니다:
#
# ```plaintext
# 1번째 출력:  1
# 2번째 출력:  2
# 3번째 출력:  3
# 4번째 출력:  4
# 5번째 출력:  5
# 6번째 출력:  6
# 7번째 출력:  7
# 8번째 출력:  8
# 9번째 출력:  9
# 10번째 출력:  10
# 11번째 출력:  11
# 12번째 출력:  12
# 13번째 출력:  13
# 14번째 출력:  14
# 15번째 출력:  15
# 16번째 출력:  16
# 17번째 출력:  17
# 18번째 출력:  18
# 19번째 출력:  19
# 20번째 출력:  20
# 최종 결과:  190
# ```
#
# 이 코드는 1부터 20까지의 숫자를 출력하고, 0부터 19까지의 숫자를 모두 더한 결과를 `result`에 저장하여 최종 결과로 출력합니다. `result`의 최종 값은 0부터 19까지의 합인 190입니다.
# ================================== Ai Message ==================================
#
# 이전 대화 기록이 제공되지 않았으므로, 내부 지식을 참조하여 질문에 답변하겠습니다.
#
# 주어진 Python 코드를 실행하면 다음과 같은 결과가 출력됩니다:
#
# ```plaintext
# 1번째 출력:  1
# 2번째 출력:  2
# 3번째 출력:  3
# 4번째 출력:  4
# 5번째 출력:  5
# 6번째 출력:  6
# 7번째 출력:  7
# 8번째 출력:  8
# 9번째 출력:  9
# 10번째 출력:  10
# 11번째 출력:  11
# 12번째 출력:  12
# 13번째 출력:  13
# 14번째 출력:  14
# 15번째 출력:  15
# 16번째 출력:  16
# 17번째 출력:  17
# 18번째 출력:  18
# 19번째 출력:  19
# 20번째 출력:  20
# 최종 결과:  190
# ```
#
# 이 코드는 1부터 20까지의 숫자를 출력하고, 0부터 19까지의 숫자를 모두 더한 결과를 `result`에 저장하여 최종 결과로 출력합니다. `result`의 최종 값은 0부터 19까지의 합인 190입니다.

# %%
config = reset_config()

streaming("""
          모두의연구소는 어떤 곳이야?
          깔끔하게 정리해서 레포트로 만들어줘.
          레포트의 형식은 pdf로 저장해주면 돼.
          이름은 "모두의연구소_레포트.pdf"로 해줘.""", config)
# Out:
# ================================ Human Message =================================
#
#
#           모두의연구소는 어떤 곳이야?
#           깔끔하게 정리해서 레포트로 만들어줘.
#           레포트의 형식은 pdf로 저장해주면 돼.
#           이름은 "모두의연구소_레포트.pdf"로 해줘.
# ================================ Human Message =================================
#
#
#           모두의연구소는 어떤 곳이야?
#           깔끔하게 정리해서 레포트로 만들어줘.
#           레포트의 형식은 pdf로 저장해주면 돼.
#           이름은 "모두의연구소_레포트.pdf"로 해줘.
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (call_6fH5ov8Yzehq8Qtp4vx7LVHM)
#  Call ID: call_6fH5ov8Yzehq8Qtp4vx7LVHM
#   Args:
#     query: 모두의연구소 소개
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "모두의연구소 2026년 기업정보 - 직원수, 근무환경, 복리후생 등", "url": "https://www.jobkorea.co.kr/recruit/co_read/c/modulabs", "content": "모두의연구소는 교육 서비스와 커뮤니티 서비스를 통하여 기술과 지식을 나누며 경쟁보다 상생을, 일방적인 교육보다 함께 만들어가는 배움을 지향하며 누구나 자신의 연구", "score": 0.9995695}, {"title": "모두의연구소 커뮤니티 | Facebook", "url": "https://www.facebook.com/groups/modulabs?locale=ko_KR", "content": "모두함께 연구하는 #모두의연구소 ( https://www.facebook.com/lab4all )에 관심있는 모든 분들이 함께 소통할 수있는 그룹을 하나 만들었습니다.", "score": 0.9991768}, {"title": "모두의연구소 공식(@modulabs_) • Instagram 사진 및 동영상", "url": "https://www.instagram.com/modulabs_?hl=ko", "content": "하지만 사티아 나델라가 소개한 GigaTIME은 동네 병원의 5달러짜리 일반 병리 슬라이드만으로 21개 채널의 암세포 단백질 지도를 완성합니다. 4천만 개 세포를 학습한", "score": 0.9990746}, {"title": "2026년 모두의연구소 채용 기업정보 - 인크루트", "url": "https://www.incruit.com/company/1681026116", "content": "모두의연구소는 교육 서비스와 커뮤니티 서비스를 통하여 기술과 지식을 나누며 경쟁보다 상생을, 일방적인 교육보다 함께 만들어가는 배움을 지향하며 누구나 자신의", "score": 0.9988213}, {"title": "모두의연구소 - YouTube", "url": "https://www.youtube.com/channel/UCv4U1uZvuxopMj8xiPXIBMQ", "content": "모두의연구소 · 이렇게 배우는 건 처음이었어요! · AI 시대, 전문가에게 듣다 · 아이펠 부트캠프ㅣ수료생 후기가 궁금하다면? · AI 강의 미리보기 | 모두의연구소 클래스 ·", "score": 0.9987649}, {"title": "모두의연구소(modulabs) | 채용, 회사소개, 연봉, 매출, 직원", "url": "https://www.rocketpunch.com/companies/modulabs", "content": "로그인 후 검색 가능\n\n홈\n\n가장 빠른 소식\n\n네트워킹\n\n이벤트 · 컨퍼런스\n\n채용\n\n새로운 기회 탐색\n\n교육\n\n부트캠프 · 직무 역량강화\n\n채팅\n\n나를 위한 소식\n\n허브\n\n기업 · 학교 · 사람 모아보기\n\n접기\n\n개인정보와 약관\n\n기업 서비스\n\n지원센터\n\n본 서비스에서 제공하는 사용자의 개인정보 데이터를 포함하여 각 정보주체의 동의 없이 데이터를 무단으로 수집하는 행위를 금지 및 거부합니다. 공개된 데이터도 크롤링 등 기술적 장치를 이용해 허가 없이 수집하는 경우 개인정보 보호법에 따라 형사처벌 될 수 있음을 알려드립니다.\n\n© 2025 Rocketpunch, 주식회사 더블에이스, 김인기, 대한민국 서울특별시 성동구 성수일로10길 12, 12층 1호, 04793, support@rocketpunch.com, +82 10-2710-7121\n사업자등록번호 206-87-09615\n통신판매업신고번호 2025-서울성동-0105\n직업정보제공사업신고번호: J1202020240015\n접기\n\n쿠키 맞춤 설정\n\n로그인\n\ncompany-banner-image\n사용자 프로필 1\n\n모두의연구소\n\n네트워크/통신/모바일 · 강남구 · 팔로워 249명\n\n게시물\n\n2\n\n팔로워\n\n249\n\n채용공고\n\n0\n\n누구나 함께 지식을 공유하고 성장하는 연구 문화를 전파합니다\n\n기업 홈\n\n게시물\n\n채용 공고\n\n사람 찾기\n\n모두의연구소\n\n관련 사람\n\n더보기\n\n박민수의 프로필 이미지\n\n박민수\n\nSW 개발 · C레벨\n\n이지석의 프로필 이미지\n\n이지석\n\n경영/운영 · C레벨\n\n서승민의 프로필 이미지\n\n서승민\n\n상담/영업 · C레벨\n\n황후순의 프로필 이미지 [...] 경영/운영 · C레벨\n\n서승민의 프로필 이미지\n\n서승민\n\n상담/영업 · C레벨\n\n황후순의 프로필 이미지\n\n황후순\n\nSW 개발 · C레벨\n\n이일구의 프로필 이미지\n\n이일구\n\nSW 개발 · 시니어\n\n조문경의 프로필 이미지\n\n조문경\n\n디자인/UX · 시니어\n\n안상혁의 프로필 이미지\n\n안상혁\n\nSW 개발 · 시니어\n\n박선우의 프로필 이미지\n\n박선우\n\n시니어\n\n강은숙의 프로필 이미지\n\n강은숙\n\nSW 개발 · 시니어\n\n황수연의 프로필 이미지\n\n황수연\n\n경영/운영 · 시니어\n\n모두의연구소\n\n기업 정보\n\n대표자\n\n김승일\n\n업종\n\n네트워크/통신/모바일\n\n고용인원\n\n63명\n\n누적투자유치\n\n-\n\n설립일\n\n2015년 12월 5일\n\n본사\n\n강남구\n(대한민국 서울특별시 강남구)\n\n관련 게시물\n\n2개\n\n더보기\n\nimage\nimage\n\n바로가기\n\nfavicon\n\nfavicon\n\n광고 문의\n\n파트너십 문의\n\nKO\n\n인기 있는 기업\n\nimage\nimage\nimage\nimage\nimage\nimage", "score": 0.9981324}, {"title": "스토리 | 모두의연구소", "url": "https://modulabs.co.kr/modulabs-story", "content": "## 모두의연구소 미션 소개\n\nOur Mission\n\n### Share Value, Grow Together\n\n함께 지식을 공유하고 성장하는 연구 문화를 전파합니다\n\nOur Mission\n\nOur Value\n\n### 모두의연구소는 “경쟁이 아닌 상생의 힘” 을 믿습니다.\n\nOur Value\n\nbackground Quote\n\n모두의연구소는 지식을 나누고 함께 성장하는 커뮤니티형 교육을 통해 더 나은 미래를 만들고자 합니다. AI 시대, 100년 전처럼 주입식으로 가르치는 교육 방식은 점점 그 의미를 잃고 있습니다.   \n   \n 우리는 사람과 사람을 연결하여 함께 웃고, 배우고, 성장하는 과정을 소중히 여기며, 세상에 필요한 지식을 함께 나누는 세상을 꿈꿉니다.\n\n모두의연구소 대표 김승일\n\n브랜딩북 열어보기\n\n## 모두의연구소 비전 소개\n\n모두의연구소는\n\n### 오늘도 AI / SW 교육 혁신을 선도하고 있습니다\n\n 커뮤니티 연구원\n\n  커뮤니티 연구원\n\n  10,212\n\n  plus\n 스터디 활동 수\n\n  스터디 활동 수\n\n  949\n\n  plus\n 탑티어 논문\n\n  탑티어 논문\n\n  100\n\n  plus\n AI / SW 졸업생\n\n  AI / SW 졸업생\n\n  1,258\n\n  plus\n\n2024\n\n2024\n\n05\n\nAI 미래포럼 공동의장단 대표 선정\n\n12\n\n과학기술정보통신부 장관 표창\n\n2023\n\n2023\n\n09\n\n2023 직업능력의 달 기념 대통령 표창\n\n10\n\nSW교육 오름캠프 교육 런칭\n\n2022\n\n2022\n\n02\n\n70억 투자 유치 (KB인베스트먼트, 대교인베스트먼트)\n\n06 [...] 모두의연구소(대표 김승일)는 ‘AI학교 아이펠’ C-로라 랩 팀이 제시한 PC-로라(LoRA) 기법에 대한 연구 결과가 ‘ICLR 2024’에 채택됐다고 15일 밝혔다.\n\nAI학교 아이펠, 글로벌 학회 ‘ICLR’에서 혁신 기술 논문 채택### 모두의연구소 김승일 대표 ‘태재미래교육포럼’에서 발표…”주입식 교육 바꾸겠다”\n\n한국판 미네르바 대학으로 알려진 태재대학교(총장 염재호)는 '인공지능 ...
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "모두의연구소 2026년 기업정보 - 직원수, 근무환경, 복리후생 등", "url": "https://www.jobkorea.co.kr/recruit/co_read/c/modulabs", "content": "모두의연구소는 교육 서비스와 커뮤니티 서비스를 통하여 기술과 지식을 나누며 경쟁보다 상생을, 일방적인 교육보다 함께 만들어가는 배움을 지향하며 누구나 자신의 연구", "score": 0.9995695}, {"title": "모두의연구소 커뮤니티 | Facebook", "url": "https://www.facebook.com/groups/modulabs?locale=ko_KR", "content": "모두함께 연구하는 #모두의연구소 ( https://www.facebook.com/lab4all )에 관심있는 모든 분들이 함께 소통할 수있는 그룹을 하나 만들었습니다.", "score": 0.9991768}, {"title": "모두의연구소 공식(@modulabs_) • Instagram 사진 및 동영상", "url": "https://www.instagram.com/modulabs_?hl=ko", "content": "하지만 사티아 나델라가 소개한 GigaTIME은 동네 병원의 5달러짜리 일반 병리 슬라이드만으로 21개 채널의 암세포 단백질 지도를 완성합니다. 4천만 개 세포를 학습한", "score": 0.9990746}, {"title": "2026년 모두의연구소 채용 기업정보 - 인크루트", "url": "https://www.incruit.com/company/1681026116", "content": "모두의연구소는 교육 서비스와 커뮤니티 서비스를 통하여 기술과 지식을 나누며 경쟁보다 상생을, 일방적인 교육보다 함께 만들어가는 배움을 지향하며 누구나 자신의", "score": 0.9988213}, {"title": "모두의연구소 - YouTube", "url": "https://www.youtube.com/channel/UCv4U1uZvuxopMj8xiPXIBMQ", "content": "모두의연구소 · 이렇게 배우는 건 처음이었어요! · AI 시대, 전문가에게 듣다 · 아이펠 부트캠프ㅣ수료생 후기가 궁금하다면? · AI 강의 미리보기 | 모두의연구소 클래스 ·", "score": 0.9987649}, {"title": "모두의연구소(modulabs) | 채용, 회사소개, 연봉, 매출, 직원", "url": "https://www.rocketpunch.com/companies/modulabs", "content": "로그인 후 검색 가능\n\n홈\n\n가장 빠른 소식\n\n네트워킹\n\n이벤트 · 컨퍼런스\n\n채용\n\n새로운 기회 탐색\n\n교육\n\n부트캠프 · 직무 역량강화\n\n채팅\n\n나를 위한 소식\n\n허브\n\n기업 · 학교 · 사람 모아보기\n\n접기\n\n개인정보와 약관\n\n기업 서비스\n\n지원센터\n\n본 서비스에서 제공하는 사용자의 개인정보 데이터를 포함하여 각 정보주체의 동의 없이 데이터를 무단으로 수집하는 행위를 금지 및 거부합니다. 공개된 데이터도 크롤링 등 기술적 장치를 이용해 허가 없이 수집하는 경우 개인정보 보호법에 따라 형사처벌 될 수 있음을 알려드립니다.\n\n© 2025 Rocketpunch, 주식회사 더블에이스, 김인기, 대한민국 서울특별시 성동구 성수일로10길 12, 12층 1호, 04793, support@rocketpunch.com, +82 10-2710-7121\n사업자등록번호 206-87-09615\n통신판매업신고번호 2025-서울성동-0105\n직업정보제공사업신고번호: J1202020240015\n접기\n\n쿠키 맞춤 설정\n\n로그인\n\ncompany-banner-image\n사용자 프로필 1\n\n모두의연구소\n\n네트워크/통신/모바일 · 강남구 · 팔로워 249명\n\n게시물\n\n2\n\n팔로워\n\n249\n\n채용공고\n\n0\n\n누구나 함께 지식을 공유하고 성장하는 연구 문화를 전파합니다\n\n기업 홈\n\n게시물\n\n채용 공고\n\n사람 찾기\n\n모두의연구소\n\n관련 사람\n\n더보기\n\n박민수의 프로필 이미지\n\n박민수\n\nSW 개발 · C레벨\n\n이지석의 프로필 이미지\n\n이지석\n\n경영/운영 · C레벨\n\n서승민의 프로필 이미지\n\n서승민\n\n상담/영업 · C레벨\n\n황후순의 프로필 이미지 [...] 경영/운영 · C레벨\n\n서승민의 프로필 이미지\n\n서승민\n\n상담/영업 · C레벨\n\n황후순의 프로필 이미지\n\n황후순\n\nSW 개발 · C레벨\n\n이일구의 프로필 이미지\n\n이일구\n\nSW 개발 · 시니어\n\n조문경의 프로필 이미지\n\n조문경\n\n디자인/UX · 시니어\n\n안상혁의 프로필 이미지\n\n안상혁\n\nSW 개발 · 시니어\n\n박선우의 프로필 이미지\n\n박선우\n\n시니어\n\n강은숙의 프로필 이미지\n\n강은숙\n\nSW 개발 · 시니어\n\n황수연의 프로필 이미지\n\n황수연\n\n경영/운영 · 시니어\n\n모두의연구소\n\n기업 정보\n\n대표자\n\n김승일\n\n업종\n\n네트워크/통신/모바일\n\n고용인원\n\n63명\n\n누적투자유치\n\n-\n\n설립일\n\n2015년 12월 5일\n\n본사\n\n강남구\n(대한민국 서울특별시 강남구)\n\n관련 게시물\n\n2개\n\n더보기\n\nimage\nimage\n\n바로가기\n\nfavicon\n\nfavicon\n\n광고 문의\n\n파트너십 문의\n\nKO\n\n인기 있는 기업\n\nimage\nimage\nimage\nimage\nimage\nimage", "score": 0.9981324}, {"title": "스토리 | 모두의연구소", "url": "https://modulabs.co.kr/modulabs-story", "content": "## 모두의연구소 미션 소개\n\nOur Mission\n\n### Share Value, Grow Together\n\n함께 지식을 공유하고 성장하는 연구 문화를 전파합니다\n\nOur Mission\n\nOur Value\n\n### 모두의연구소는 “경쟁이 아닌 상생의 힘” 을 믿습니다.\n\nOur Value\n\nbackground Quote\n\n모두의연구소는 지식을 나누고 함께 성장하는 커뮤니티형 교육을 통해 더 나은 미래를 만들고자 합니다. AI 시대, 100년 전처럼 주입식으로 가르치는 교육 방식은 점점 그 의미를 잃고 있습니다.   \n   \n 우리는 사람과 사람을 연결하여 함께 웃고, 배우고, 성장하는 과정을 소중히 여기며, 세상에 필요한 지식을 함께 나누는 세상을 꿈꿉니다.\n\n모두의연구소 대표 김승일\n\n브랜딩북 열어보기\n\n## 모두의연구소 비전 소개\n\n모두의연구소는\n\n### 오늘도 AI / SW 교육 혁신을 선도하고 있습니다\n\n 커뮤니티 연구원\n\n  커뮤니티 연구원\n\n  10,212\n\n  plus\n 스터디 활동 수\n\n  스터디 활동 수\n\n  949\n\n  plus\n 탑티어 논문\n\n  탑티어 논문\n\n  100\n\n  plus\n AI / SW 졸업생\n\n  AI / SW 졸업생\n\n  1,258\n\n  plus\n\n2024\n\n2024\n\n05\n\nAI 미래포럼 공동의장단 대표 선정\n\n12\n\n과학기술정보통신부 장관 표창\n\n2023\n\n2023\n\n09\n\n2023 직업능력의 달 기념 대통령 표창\n\n10\n\nSW교육 오름캠프 교육 런칭\n\n2022\n\n2022\n\n02\n\n70억 투자 유치 (KB인베스트먼트, 대교인베스트먼트)\n\n06 [...] 모두의연구소(대표 김승일)는 ‘AI학교 아이펠’ C-로라 랩 팀이 제시한 PC-로라(LoRA) 기법에 대한 연구 결과가 ‘ICLR 2024’에 채택됐다고 15일 밝혔다.\n\nAI학교 아이펠, 글로벌 학회 ‘ICLR’에서 혁신 기술 논문 채택### 모두의연구소 김승일 대표 ‘태재미래교육포럼’에서 발표…”주입식 교육 바꾸겠다”\n\n한국판 미네르바 대학으로 알려진 태재대학교(총장 염재호)는 '인공지능 ...
# ================================== Ai Message ==================================
# Tool Calls:
#   write_pdf (call_yf2p1AmiY6TDspm03T38P6tx)
#  Call ID: call_yf2p1AmiY6TDspm03T38P6tx
#   Args:
#     content: 모두의연구소는 교육 서비스와 커뮤니티 서비스를 통해 기술과 지식을 나누며, 경쟁보다 상생을, 일방적인 교육보다 함께 만들어가는 배움을 지향하는 곳입니다. 누구나 자신의 연구를 자유롭게 할 수 있는 환경을 제공하며, AI 시대에 맞춰 주입식 교육이 아닌 상호작용을 통한 학습을 중요시합니다.\n\n모두의연구소는 다양한 교육 프로그램과 커뮤니티 활동을 통해 AI 및 SW 교육 혁신을 선도하고 있으며, 연구원들이 함께 성장할 수 있는 문화를 조성하고 있습니다.\n\n대표자: 김승일\n설립일: 2015년 12월 5일\n본사 위치: 서울특별시 강남구\n주요 서비스: AI 교육, 커뮤니티 서비스, 연구 지원\n\n모두의연구소는 AI 연구 커뮤니티와 AI-SW 인재 육성 사업을 통해 대한민국의 인공지능 연구 생태계를 더욱 풍요롭게 만들어가고자 합니다. 다양한 연구소, 기업, 대학들과 협업하며, 지속적인 성장을 지원하는 탄탄한 인공지능 커뮤니티를 운영하고 있습니다.
#     filename: 모두의연구소_레포트.pdf
# ================================= Tool Message =================================
# Name: write_pdf
#
# 모두의연구소_레포트.pdf 저장 완료
# ================================= Tool Message =================================
# Name: write_pdf
#
# 모두의연구소_레포트.pdf 저장 완료

# %%
config = reset_config()

query = "'모두의연구소_레포트.pdf'라는 파일 삭제해줘"

streaming(query, config)
# Out:
# ================================ Human Message =================================
#
# '모두의연구소_레포트.pdf'라는 파일 삭제해줘
# ================================ Human Message =================================
#
# '모두의연구소_레포트.pdf'라는 파일 삭제해줘
# ================================== Ai Message ==================================
# Tool Calls:
#   file_delete (call_4aOA2gcU1izSx9iiPgDQre8Y)
#  Call ID: call_4aOA2gcU1izSx9iiPgDQre8Y
#   Args:
#     file_path: 모두의연구소_레포트.pdf
# ================================= Tool Message =================================
# Name: file_delete
#
# File deleted successfully: 모두의연구소_레포트.pdf.
# ================================= Tool Message =================================
# Name: file_delete
#
# File deleted successfully: 모두의연구소_레포트.pdf.
